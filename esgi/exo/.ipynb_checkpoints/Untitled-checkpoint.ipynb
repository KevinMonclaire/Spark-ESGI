# %%
from pyspark.sql import SparkSession 
from pyspark.sql.functions import *
from datetime import date
from pyspark.sql.types import BooleanType
import pyspark.sql.functions as F

spark = SparkSession.builder.appName("my-spark-app").config("spark.ui.port","5050").getOrCreate()
df = spark.read.format("csv").option("header", "true").load("../../df_matches.csv")
df.printSchema()
df2 = df.withColumnRenamed("X4","match").withColumnRenamed("X6","competition")
df2.printSchema()
df2.select('match', 'competition', 'adversaire', 'score_france', 'score_adversaire', 'penalty_france', 'penalty_adversaire', 'date').show()

def blank_as_zero(x):
    return when(col(x) != "NA", col(x)).otherwise(0)

dfWithEmptyReplaced = df2.withColumn("penalty_france", blank_as_zero("penalty_france")).withColumn("penalty_adversaire", blank_as_zero("penalty_adversaire"))
dfWithEmptyReplaced.show()

today = date.today().strftime("%Y-%m-%d")
dfFiltered = dfWithEmptyReplaced.filter((dfWithEmptyReplaced.date >= '1980-03-01') & (dfWithEmptyReplaced.date <= today))
dfFiltered.show()

def isDomicile(match):
    if match.split('-')[0] == "France":
        res = True
    else:
        res = False
    return res

isDomicile_udf = F.udf(extract_title, BooleanType())

dfFiltered.withColumn('domicile', isDomicile_udf(dfFiltered.match)).show()

dfFiltered.select(avg('score_france').alias('stat1')).write.parquet('stat1.parquet')
# Out:
# root
#  |-- X2: string (nullable = true)
#  |-- X4: string (nullable = true)
#  |-- X5: string (nullable = true)
#  |-- X6: string (nullable = true)
#  |-- adversaire: string (nullable = true)
#  |-- score_france: string (nullable = true)
#  |-- score_adversaire: string (nullable = true)
#  |-- penalty_france: string (nullable = true)
#  |-- penalty_adversaire: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- outcome: string (nullable = true)
#  |-- no: string (nullable = true)
#
# root
#  |-- X2: string (nullable = true)
#  |-- match: string (nullable = true)
#  |-- X5: string (nullable = true)
#  |-- competition: string (nullable = true)
#  |-- adversaire: string (nullable = true)
#  |-- score_france: string (nullable = true)
#  |-- score_adversaire: string (nullable = true)
#  |-- penalty_france: string (nullable = true)
#  |-- penalty_adversaire: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- outcome: string (nullable = true)
#  |-- no: string (nullable = true)
#
# +-------------------+--------------------+----------+------------+----------------+--------------+------------------+----------+
# |              match|         competition|adversaire|score_france|score_adversaire|penalty_france|penalty_adversaire|      date|
# +-------------------+--------------------+----------+------------+----------------+--------------+------------------+----------+
# |  Belgique - France|        Match amical|  Belgique|           3|               3|            NA|                NA|1904-05-01|
# |    France - Suisse|        Match amical|    Suisse|           1|               0|            NA|                NA|1905-02-12|
# |  Belgique - France|        Match amical|  Belgique|           0|               7|            NA|                NA|1905-05-07|
# |  France - Belgique|        Match amical|  Belgique|           0|               5|            NA|                NA|1906-04-22|
# |France - Angleterre|        Match amical|Angleterre|           0|               1|            NA|                NA|1906-11-01|
# |  Belgique - France|        Match amical|  Belgique|           2|               1|            NA|                NA|1907-04-21|
# |    Suisse - France|        Match amical|    Suisse|           2|               1|            NA|                NA|1908-03-08|
# | 18 février 1981|    Espagne - France|1-0|        Match amical|        Espagne|           0|               1|             0|                 0|1981-02-18|1981|   loss|  1|   false|
# |    25 mars 1981|   Pays-Bas - France|1-0|Qualifications po...|       Pays-Bas|           0|               1|             0|                 0|1981-03-25|1981|   loss|  2|   false|
# |   29 avril 1981|   France - Belgique|3-2|Qualifications po...|       Belgique|           3|               2|             0|                 0|1981-04-29|1981|    win|  3|    true|
# |     15 mai 1981|     France - Brésil|1-3|        Match amical|         Brésil|           1|               3|             0|                 0|1981-05-15|1981|   loss|  4|    true|
# |9 septembre 1981|   Belgique - France|2-0|Qualifications po...|       Belgique|           0|               2|             0|                 0|1981-09-09|1981|   loss|  5|   false|
# | 14 octobre 1981|    Irlande - France|3-2|Qualifications po...|        Irlande|           2|               3|             0|                 0|1981-10-14|1981|   loss|  6|   false|
# |18 novembre 1981|   France - Pays-Bas|2-0|Qualifications po...|       Pays-Bas|           2|               0|             0|                 0|1981-11-18|1981|    win|  7|    true|
# | 5 décembre 1981|     France - Chypre|4-0|Qualifications po...|         Chypre|           4|               0|             0|                 0|1981-12-05|1981|    win|  8|    true|
# | 23 février 1982|     France - Italie|2-0|        Match amical|         Italie|           2|               0|             0|                 0|1982-02-23|1982|    win|  1|    true|
# |    24 mars 1982|France - Irlande ...|4-0|        Match amical|Irlande du Nord|           4|               0|             0|                 0|1982-03-24|1982|    win|  2|    true|
# |   28 avril 1982|      France - Pérou|0-1|        Match amical|          Pérou|           0|               1|             0|                 0|1982-04-28|1982|   loss|  3|    true|
# |     15 mai 1982|   France - Bulgarie|0-0|        Match amical|       Bulgarie|           0|               0|             0|                 0|1982-05-15|1982|   draw|  4|    true|
# |     2 juin 1982|France - Pays de ...|0-1|        Match amical| Pays de Galles|           0|               1|             0|                 0|1982-06-02|1982|   loss|  5|    true|
# |    16 juin 1982| Angleterre - France|3-1|Coupe du monde 19...|     Angleterre|           1|               3|             0|                 0|1982-06-16|1982|   loss|  6|   false|
# |    21 juin 1982|     France - Koweït|4-1|Coupe du monde 19...|         Koweït|           4|               1|             0|                 0|1982-06-21|1982|    win|  7|    true|
# +----------------+--------------------+---+--------------------+---------------+------------+----------------+--------------+------------------+----------+----+-------+---+--------+
# only showing top 20 rows
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-53-c2720ce8a30a> in <module>
#      33 dfFiltered.withColumn('domicile', isDomicile_udf(dfFiltered.match)).show()
#      34
# ---> 35 dfFiltered.select(avg('score_france')).write.parquet('stat1.parquet').withColumnRenamed("avg('score_france')", 'stat1')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyspark/sql/readwriter.py in parquet(self, path, mode, partitionBy, compression)
#    1247             self.partitionBy(partitionBy)
#    1248         self._set_opts(compression=compression)
# -> 1249         self._jwrite.parquet(path)
#    1250
#    1251     def text(self, path, compression=None, lineSep=None):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# AnalysisException: Attribute name "avg(score_france)" contains invalid character(s) among " ,;{}()\n\t=". Please use alias to rename it.
